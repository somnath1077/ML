# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
seed(1000)
bank_balance = np.array([random.randint(2000, 6000) for _ in range(100)]).reshape(-1, 1)
credit_worthiness = np.array([int(bank_balance[i] > 4000) for i in range(100)]).reshape(-1, 1)

# %%
plt.scatter(bank_balance, credit_worthiness)
plt.xlabel('Bank Balance')

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(bank_balance, credit_worthiness)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y = lin_reg.predict(bank_balance)

# %%
plt.plot(bank_balance, y, color='blue', linewidth=2)
plt.axvline(x=4000)
plt.show()

# %%
bank_balanceb2 = np.array([randint(8000, 20000) for _ in range(100)]).reshape(-1, 1)
bank_balance_final = np.concatenate((bank_balance, bank_balance2), axis=0)
credit_worthiness_final = np.array([int(bank_balance_final[i] > 4000) for i in range(200)]).reshape(-1, 1)

# %%
plt.scatter(bank_balance_final, credit_worthiness_final)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(bank_balance_final, credit_worthiness_final)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y2 = lin_reg2.predict(bank_balance_final)

# %%
# plt.plot(bank_balance_final, y2, color='red', linewidth=2)
# plt.show()

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(bank_balance, y, c='b', label='first')
ax1.plot(bank_balance_final, y2, c='r', label='second')
plt.axvline(x=4000)
plt.legend(loc='upper left');
plt.show()
