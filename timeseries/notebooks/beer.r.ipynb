# %%
FILEPATH <- '../R/beer.R'

source(FILEPATH)

# %%
beer
# Out:
#      Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 1991 164 148 152 144 155 125 153 146 138 190 192 192
# 1992 147 133 163 150 129 131 145 137 138 168 176 188
# 1993 139 143 150 154 137 129 128 140 143 151 177 184
# 1994 151 134 164 126 131 125 127 143 143 160 190 182
# 1995 138 136 152 127 151 130 119 153

# %%
head(beer)
# Out:
# [1] 164 148 152 144 155 125

# %%
length(beer)
# Out:
# [1] 56

# %%
write.csv(beer, "../data/beer.csv")

# %%
plot.ts(beer)
dev.new(width=5, height=4)
# Out:
# plot without title

# %%
mean(beer)
# Out:
# [1] 149.3036

# %%
56 * log(2) / log(10)
# Out:
# [1] 16.85768

# %%
cov <- acf(beer, type = "correlation", lag = 24)
cov
# Out:
# Autocorrelations of series ‘beer’, by lag
#
# 0.0000 0.0833 0.1667 0.2500 0.3333 0.4167 0.5000 0.5833 0.6667 0.7500 0.8333
#  1.000  0.421  0.057 -0.059 -0.188 -0.287 -0.424 -0.343 -0.156 -0.008  0.051
# 0.9167 1.0000 1.0833 1.1667 1.2500 1.3333 1.4167 1.5000 1.5833 1.6667 1.7500
#  0.374  0.596  0.303  0.082 -0.077 -0.179 -0.158 -0.302 -0.259 -0.117 -0.034
# 1.8333 1.9167 2.0000
#  0.012  0.252  0.385
# Plot with title “Series  beer”

# %%
acf(beer, type = "correlation", plot = TRUE)
dev.new(width=4, height=3)
# Out:
# Plot with title “Series  beer”
